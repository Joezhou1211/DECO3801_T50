# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# 加载数据
df = pd.read_csv('tweets_with_topics.csv')

# 使用 TfidfVectorizer 将文本转换为TF-IDF矩阵
vectorizer = TfidfVectorizer(max_features=1000, stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['cleaned_text'])

# 训练 NMF 模型
num_topics = 10
nmf_model = NMF(n_components=num_topics, random_state=1)
W = nmf_model.fit_transform(tfidf_matrix)
H = nmf_model.components_

# 将每个推文的主题分布添加到数据框中
for i in range(num_topics):
    df[f'topic_{i}'] = W[:, i]

# 显示数据框的前几行
df.head()

# 保存结果
df.to_csv('tweets_with_nmf_topics.csv', index=False)
# Out:
#                    _id               author  parent  quoted  \
# 0  1115392002538004481             38344185     NaN     NaN
# 1  1116083380783857664  1062205038393724929     NaN     NaN
# 2  1118173762615218176            524438893     NaN     NaN
# 3  1120493234801840129            525812268     NaN     NaN
# 4  1120940885733101570             93766096     NaN     NaN
#
#                                           mentions hashtags  depth node_type  \
# 0                                     ['38344185']       []      0      Root
# 1                          ['1062205038393724929']       []      0      Root
# 2                                    ['524438893']       []      0      Root
# 3  ['799911790398373888', '525812268', '63942152']       []      0      Root
# 4                        ['525812268', '93766096']       []      0      Root
#
#   quote_ancestors tweet_ancestors  ...          deidentname        timebucket  \
# 0              []              []  ...  Michael Matthew Lee  2019-04-08 23:00
# 1              []              []  ...            Ann Smith  2019-04-10 20:45
# 2              []              []  ...        Jente Guthrie  2019-04-16 15:15
# 3              []              []  ...       Patricia Alves  2019-04-23 01:00
# 4              []              []  ...           Ann George  2019-04-24 06:30
#
#   horiz_offset influence_tweet_factor   left  vert_offset       location  \
# 0          0.5               1.866287  False     0.834444        Unknown
# 1          0.5               2.819544   True     0.986667        Unknown
# 2          0.5               2.363612   True     0.748889  United States
# 3          0.5               1.931966   True     0.198889        Unknown
# 4          0.5               2.532117   True     0.785556        Unknown
#
#   vert_correct                                       cleaned_text  \
# 0         True  rock roll dream angelina jolie bad rock roll d...
# 1         True                                 screaming need see
# 2         True  seriously never easy create great marketing video
# 3         True  morning viktoriarusso patriciaalves amp announ...
# 4         True  wonderful welcome katyrobertson mosman rowing ...
#
#   dominant_topic
# 0              9
# 1              3
# 2              6
# 3              1
# 4              9
#
# [5 rows x 45 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 12
#       9 def keyword_filter(text):
#      10     return any(keyword in text.lower() for keyword in bushfire_keywords)
# ---> 12 bushfire_tweets = df[df['cleaned_text'].apply(keyword_filter)]
#      14 # 显示过滤后的数据框架的前几行
#      15 bushfire_tweets.head()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[5], line 10, in keyword_filter(text)
#       9 def keyword_filter(text):
# ---> 10     return any(keyword in text.lower() for keyword in bushfire_keywords)
#
# Cell In[5], line 10, in <genexpr>(.0)
#       9 def keyword_filter(text):
# ---> 10     return any(keyword in text.lower() for keyword in bushfire_keywords)
#
# AttributeError: 'float' object has no attribute 'lower'
