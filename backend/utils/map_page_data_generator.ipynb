# %%
import pandas as pd

df = pd.read_csv('../../data/raw/v_forest.csv')
# Out:
# /var/folders/sn/vtf5wp8x6vldjnk3w88mk9zr0000gn/T/ipykernel_39339/882032220.py:3: DtypeWarning: Columns (0,1,6,14,15,16,32,39,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/raw/v_forest.csv')

# %%
df.head()
# Out:
#                   _id      author  parent  quoted  \
# 0          3787575861    34116377     NaN     NaN
# 1          5433639942    34116377     NaN     NaN
# 2  289077574649409537   335469402     NaN     NaN
# 3  316243081693384705   335469402     NaN     NaN
# 4  345123067816706048  1512911756     NaN     NaN
#
#                                             mentions  \
# 0                                       ['34116377']
# 1                                       ['34116377']
# 2                                      ['335469402']
# 3  ['347665801', '335469402', '288009920', '28085...
# 4                                     ['1512911756']
#
#                                             hashtags depth node_type  \
# 0                                                 []     0      Root
# 1                                                 []     0      Root
# 2  ['bushfires', 'scorchio', 'australia', 'weather']     0      Root
# ...

# %%
# Drop data with empty display_text
df = df.dropna(subset=['display_text'])
# Extract 'ArsonEmergency' and update to df_arson
df_arson = df[df['display_text'].str.contains('ArsonEmergency')]

# %%
df_arson.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1399 entries, 12122 to 487438
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _id                     1399 non-null   object
#  1   author                  1399 non-null   object
#  2   parent                  456 non-null    float64
#  3   quoted                  596 non-null    float64
#  4   mentions                1399 non-null   object
#  5   hashtags                1399 non-null   object
#  6   depth                   1399 non-null   object
#  7   node_type               1399 non-null   object
#  8   quote_ancestors         1399 non-null   object
#  9   tweet_ancestors         1399 non-null   object
#  10  children                1399 non-null   float64
#  11  tree_authors            1399 non-null   object
#  12  tree_hashtags           1399 non-null   object
#  13  tree_users              1399 non-null   object
# ...

# %%
# Extract data with AustraliaFire and update to df_fire
df_fire = df[df['display_text'].str.contains('AustraliaFire')]

# %%
df_fire.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60928 entries, 5278 to 490650
# Data columns (total 43 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _id                     60928 non-null  object
#  1   author                  60928 non-null  object
#  2   parent                  7818 non-null   float64
#  3   quoted                  14029 non-null  float64
#  4   mentions                60928 non-null  object
#  5   hashtags                60928 non-null  object
#  6   depth                   60928 non-null  object
#  7   node_type               60928 non-null  object
#  8   quote_ancestors         60928 non-null  object
#  9   tweet_ancestors         60928 non-null  object
#  10  children                60928 non-null  float64
#  11  tree_authors            60928 non-null  object
#  12  tree_hashtags           60928 non-null  object
#  13  tree_users              60928 non-null  object
# ...
